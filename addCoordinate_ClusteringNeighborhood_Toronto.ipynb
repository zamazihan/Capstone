# %%
#import the relevant libraries
#make sure geocaoder is installed
import geocoder # for this exercise I am using geocoder to get the coordinate
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('canada_postal.csv')
df.head(5)
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
lat = [] #create empty list of latitude(here we use 'lat' as the variable name)
long = [] #create empty list of longitude(here we use 'long' as the variable name)
i = 0

for i in range (len(df['PostalCode'])):
    postal = df['PostalCode'][i]
    g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal))
    lat_lng_coord = g.latlng
    lat.append(lat_lng_coord[0]) #append the latitude into 'lat' list
    long.append(lat_lng_coord[1]) #append the longitude into 'long' list
    i+=1

df['Latitude'] = lat #insert the latitude column into the table 'df'
df['Longitude'] = long #insert the longitude column into the table 'df'

df.head(10)
# Out:
#   PostalCode      Borough                                     Neighborhood  \
# 0        M1B  Scarborough                                   Rouge, Malvern
# 1        M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough                Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                           Woburn
# 4        M1H  Scarborough                                        Cedarbrae
# 5        M1J  Scarborough                              Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7        M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8        M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N  Scarborough                      Birch Cliff, Cliffside West
#
#     Latitude  Longitude
# 0  43.811525 -79.195517
# 1  43.785730 -79.158750
# 2  43.765690 -79.175256
# 3  43.768359 -79.217590
# ...

# %%
df.to_csv('canada_coordinate.csv', index = False)
